# %% [markdown]
# <a href="https://colab.research.google.com/github/sfuentescamara/10-kivy/blob/new_structure/Kivy_App_To_APK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install buildozer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting buildozer
#   Downloading buildozer-1.5.0-py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.9/86.9 KB 3.0 MB/s eta 0:00:00
# Collecting sh
#   Downloading sh-2.0.2-py3-none-any.whl (38 kB)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from buildozer) (4.8.0)
# Collecting virtualenv
#   Downloading virtualenv-20.20.0-py3-none-any.whl (8.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 44.8 MB/s eta 0:00:00
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->buildozer) (0.7.0)
# Requirement already satisfied: platformdirs<4,>=2.4 in /usr/local/lib/python3.8/dist-packages (from virtualenv->buildozer) (3.0.0)
# Requirement already satisfied: filelock<4,>=3.4.1 in /usr/local/lib/python3.8/dist-packages (from virtualenv->buildozer) (3.9.0)
# Collecting distlib<1,>=0.3.6
#   Downloading distlib-0.3.6-py2.py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.5/468.5 KB 24.4 MB/s eta 0:00:00
# Installing collected packages: distlib, virtualenv, sh, buildozer
# Successfully installed buildozer-1.5.0 distlib-0.3.6 sh-2.0.2 virtualenv-20.20.0

# %%
# !pip install cython==0.29.19
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting cython==0.29.19
#   Downloading Cython-0.29.19-cp38-cp38-manylinux1_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 8.7 MB/s eta 0:00:00
# Installing collected packages: cython
#   Attempting uninstall: cython
#     Found existing installation: Cython 0.29.33
#     Uninstalling Cython-0.29.33:
#       Successfully uninstalled Cython-0.29.33
# Successfully installed cython-0.29.19

# %%
# !sudo apt-get install -y \
    python3-pip \
    build-essential \
    git \
    python3 \
    python3-dev \
    ffmpeg \
    libsdl2-dev \
    libsdl2-image-dev \
    libsdl2-mixer-dev \
    libsdl2-ttf-dev \
    libportmidi-dev \
    libswscale-dev \
    libavformat-dev \
    libavcodec-dev \
    zlib1g-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python3 is already the newest version (3.8.2-0ubuntu2).
# python3 set to manually installed.
# python3-dev is already the newest version (3.8.2-0ubuntu2).
# python3-dev set to manually installed.
# build-essential is already the newest version (12.8ubuntu1.1).
# git is already the newest version (1:2.25.1-1ubuntu3.10).
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-2ubuntu1.5).
# zlib1g-dev set to manually installed.
# ffmpeg is already the newest version (7:4.2.7-0ubuntu0.1).
# libavcodec-dev is already the newest version (7:4.2.7-0ubuntu0.1).
# libavcodec-dev set to manually installed.
# libavformat-dev is already the newest version (7:4.2.7-0ubuntu0.1).
# libavformat-dev set to manually installed.
# libswscale-dev is already the newest version (7:4.2.7-0ubuntu0.1).
# libswscale-dev set to manually installed.
# The following additional packages will be installed:
#   libblkid-dev libdbus-1-dev libegl1-mesa-dev libffi-dev libfluidsynth2
#   libgl1-mesa-dev libgles-dev libgles1 libgles2-mesa-dev libglib2.0-dev
#   libglib2.0-dev-bin libglvnd-dev libibus-1.0-dev libinstpatch-1.0-2
#   libmodplug1 libmount-dev libopengl-dev libopusfile0 libportmidi0
#   libpulse-dev libsdl2-image-2.0-0 libsdl2-mixer-2.0-0 libsdl2-ttf-2.0-0
#   libselinux1-dev libsepol1-dev libsndio-dev libudev-dev libwayland-bin
#   libwayland-dev libxcursor-dev libxfixes-dev libxi-dev libxinerama-dev
#   libxkbcommon-dev libxrandr-dev libxv-dev libxxf86vm-dev python-pip-whl
#   python3-setuptools python3-wheel timgm6mb-soundfont x11proto-input-dev
#   x11proto-randr-dev x11proto-xf86vidmode-dev x11proto-xinerama-dev
# Suggested packages:
#   libgirepository1.0-dev libglib2.0-doc libgdk-pixbuf2.0-bin
#   | libgdk-pixbuf2.0-dev libxml2-utils libwayland-doc python-setuptools-doc
#   fluid-soundfont-gm fluidsynth timidity musescore
# The following NEW packages will be installed:
#   libblkid-dev libdbus-1-dev libegl1-mesa-dev libffi-dev libfluidsynth2
#   libgl1-mesa-dev libgles-dev libgles1 libgles2-mesa-dev libglib2.0-dev
#   libglib2.0-dev-bin libglvnd-dev libibus-1.0-dev libinstpatch-1.0-2
#   libmodplug1 libmount-dev libopengl-dev libopusfile0 libportmidi-dev
#   libportmidi0 libpulse-dev libsdl2-dev libsdl2-image-2.0-0 libsdl2-image-dev
#   libsdl2-mixer-2.0-0 libsdl2-mixer-dev libsdl2-ttf-2.0-0 libsdl2-ttf-dev
#   libselinux1-dev libsepol1-dev libsndio-dev libudev-dev libwayland-bin
#   libwayland-dev libxcursor-dev libxfixes-dev libxi-dev libxinerama-dev
#   libxkbcommon-dev libxrandr-dev libxv-dev libxxf86vm-dev python-pip-whl
#   python3-pip python3-setuptools python3-wheel timgm6mb-soundfont
#   x11proto-input-dev x11proto-randr-dev x11proto-xf86vidmode-dev
#   x11proto-xinerama-dev
# 0 upgraded, 51 newly installed, 0 to remove and 19 not upgraded.
# Need to get 13.0 MB of archives.
# After this operation, 42.4 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libdbus-1-dev amd64 1.12.16-2ubuntu2.3 [167 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgles1 amd64 1.3.2-1~ubuntu0.20.04.2 [10.3 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgles-dev amd64 1.3.2-1~ubuntu0.20.04.2 [47.9 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libopengl-dev amd64 1.3.2-1~ubuntu0.20.04.2 [3,584 B]
# Get:5 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libglvnd-dev amd64 1.3.2-1~ubuntu0.20.04.2 [11.6 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libegl1-mesa-dev amd64 21.2.6-0ubuntu0.1~20.04.2 [7,760 B]
# Get:7 http://archive.ubuntu.com/ubuntu focal/universe amd64 libinstpatch-1.0-2 amd64 1.1.2-2build1 [238 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal/universe amd64 timgm6mb-soundfont all 1.3-3 [5,420 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal/universe amd64 libfluidsynth2 amd64 2.1.1-2 [198 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgles2-mesa-dev amd64 21.2.6-0ubuntu0.1~20.04.2 [6,424 B]
# Get:11 http://archive.ubuntu.com/ubuntu focal/main amd64 libffi-dev amd64 3.3-4 [57.0 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libglib2.0-dev-bin amd64 2.64.6-1~ubuntu20.04.4 [109 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libblkid-dev amd64 2.34-0.1ubuntu9.3 [167 kB]
# Get:14 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libmount-dev amd64 2.34-0.1ubuntu9.3 [176 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libsepol1-dev amd64 3.0-1ubuntu0.1 [325 kB]
# Get:16 http://archive.ubuntu.com/ubuntu focal/main amd64 libselinux1-dev amd64 3.0-1build2 [151 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libglib2.0-dev amd64 2.64.6-1~ubuntu20.04.4 [1,506 kB]
# Get:18 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libibus-1.0-dev amd64 1.5.22-2ubuntu2.1 [179 kB]
# Get:19 http://archive.ubuntu.com/ubuntu focal/universe amd64 libmodplug1 amd64 1:0.8.9.0-2build1 [150 kB]
# Get:20 http://archive.ubuntu.com/ubuntu focal/universe amd64 libopusfile0 amd64 0.9+20170913-1build1 [38.8 kB]
# Get:21 http://archive.ubuntu.com/ubuntu focal/universe amd64 libportmidi0 amd64 1:217-6 [17.8 kB]
# Get:22 http://archive.ubuntu.com/ubuntu focal/universe amd64 libportmidi-dev amd64 1:217-6 [52.2 kB]
# Get:23 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libpulse-dev amd64 1:13.99.1-1ubuntu3.13 [72.5 kB]
# Get:24 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgl1-mesa-dev amd64 21.2.6-0ubuntu0.1~20.04.2 [6,420 B]
# Get:25 http://archive.ubuntu.com/ubuntu focal/universe amd64 libsndio-dev amd64 1.5.0-3 [13.6 kB]
# Get:26 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libudev-dev amd64 245.4-4ubuntu3.19 [19.7 kB]
# Get:27 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libwayland-bin amd64 1.18.0-1ubuntu0.1 [20.2 kB]
# Get:28 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libwayland-dev amd64 1.18.0-1ubuntu0.1 [64.6 kB]
# Get:29 http://archive.ubuntu.com/ubuntu focal/main amd64 libxfixes-dev amd64 1:5.0.3-2 [11.4 kB]
# Get:30 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcursor-dev amd64 1:1.2.0-2 [26.5 kB]
# Get:31 http://archive.ubuntu.com/ubuntu focal/main amd64 x11proto-input-dev all 2019.2-1ubuntu1 [2,628 B]
# Get:32 http://archive.ubuntu.com/ubuntu focal/main amd64 libxi-dev amd64 2:1.7.10-0ubuntu1 [187 kB]
# Get:33 http://archive.ubuntu.com/ubuntu focal/main amd64 x11proto-xinerama-dev all 2019.2-1ubuntu1 [2,628 B]
# Get:34 http://archive.ubuntu.com/ubuntu focal/main amd64 libxinerama-dev amd64 2:1.1.4-2 [7,896 B]
# Get:35 http://archive.ubuntu.com/ubuntu focal/main amd64 libxkbcommon-dev amd64 0.10.0-1 [45.4 kB]
# Get:36 http://archive.ubuntu.com/ubuntu focal/main amd64 x11proto-randr-dev all 2019.2-1ubuntu1 [2,620 B]
# Get:37 http://archive.ubuntu.com/ubuntu focal/main amd64 libxrandr-dev amd64 2:1.5.2-0ubuntu1 [25.0 kB]
# Get:38 http://archive.ubuntu.com/ubuntu focal/main amd64 libxv-dev amd64 2:1.0.11-1 [32.5 kB]
# Get:39 http://archive.ubuntu.com/ubuntu focal/main amd64 x11proto-xf86vidmode-dev all 2019.2-1ubuntu1 [2,624 B]
# Get:40 http://archive.ubuntu.com/ubuntu focal/main amd64 libxxf86vm-dev amd64 1:1.1.4-1build1 [13.3 kB]
# Get:41 http://archive.ubuntu.com/ubuntu focal/universe amd64 libsdl2-dev amd64 2.0.10+dfsg1-3 [718 kB]
# Get:42 http://archive.ubuntu.com/ubuntu focal/universe amd64 libsdl2-image-2.0-0 amd64 2.0.5+dfsg1-2 [63.8 kB]
# Get:43 http://archive.ubuntu.com/ubuntu focal/universe amd64 libsdl2-image-dev amd64 2.0.5+dfsg1-2 [69.4 kB]
# Get:44 http://archive.ubuntu.com/ubuntu focal/universe amd64 libsdl2-mixer-2.0-0 amd64 2.0.4+dfsg1-2build1 [60.2 kB]
# Get:45 http://archive.ubuntu.com/ubuntu focal/universe amd64 libsdl2-mixer-dev amd64 2.0.4+dfsg1-2build1 [75.7 kB]
# Get:46 http://archive.ubuntu.com/ubuntu focal/universe amd64 libsdl2-ttf-2.0-0 amd64 2.0.15+dfsg1-1 [15.6 kB]
# Get:47 http://archive.ubuntu.com/ubuntu focal/universe amd64 libsdl2-ttf-dev amd64 2.0.15+dfsg1-1 [20.5 kB]
# Ign:48 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 python-pip-whl all 20.0.2-5ubuntu1.7
# Get:49 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-setuptools all 45.2.0-1ubuntu0.1 [330 kB]
# Get:50 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 python3-wheel all 0.34.2-1ubuntu0.1 [23.9 kB]
# Ign:51 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 python3-pip all 20.0.2-5ubuntu1.7
# Err:48 http://security.ubuntu.com/ubuntu focal-updates/universe amd64 python-pip-whl all 20.0.2-5ubuntu1.7
#   404  Not Found [IP: 91.189.91.39 80]
# Err:51 http://security.ubuntu.com/ubuntu focal-updates/universe amd64 python3-pip all 20.0.2-5ubuntu1.7
#   404  Not Found [IP: 91.189.91.39 80]
# Fetched 11.0 MB in 2s (4,615 kB/s)
# E: Failed to fetch http://security.ubuntu.com/ubuntu/pool/universe/p/python-pip/python-pip-whl_20.0.2-5ubuntu1.7_all.deb  404  Not Found [IP: 91.189.91.39 80]
# E: Failed to fetch http://security.ubuntu.com/ubuntu/pool/universe/p/python-pip/python3-pip_20.0.2-5ubuntu1.7_all.deb  404  Not Found [IP: 91.189.91.39 80]
# E: Unable to fetch some archives, maybe run apt-get update or try with --fix-missing?

# %%
# !sudo apt-get install -y \
    libgstreamer1.0 \
    gstreamer1.0-plugins-base \
    gstreamer1.0-plugins-good
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'libgstreamer1.0-dev' for regex 'libgstreamer1.0'
# Note, selecting 'libgstreamer1.0-0-dbg' for regex 'libgstreamer1.0'
# Note, selecting 'libgstreamer1.0-0' for regex 'libgstreamer1.0'
# libgstreamer1.0-0 is already the newest version (1.16.3-0ubuntu1.1).
# libgstreamer1.0-0 set to manually installed.
# The following additional packages will be installed:
#   autopoint debhelper dh-autoreconf dh-strip-nondeterminism dwz gettext
#   gettext-base gir1.2-gstreamer-1.0 gstreamer1.0-x intltool-debian libaa1
#   libarchive-cpio-perl libarchive-zip-perl libblkid-dev libcdparanoia0
#   libcroco3 libdebhelper-perl libdv4 libffi-dev
#   libfile-stripnondeterminism-perl libglib2.0-dev libglib2.0-dev-bin
#   libgstreamer-plugins-good1.0-0 libmail-sendmail-perl libmount-dev
#   libselinux1-dev libsepol1-dev libshout3 libsub-override-perl
#   libsys-hostname-long-perl libtag1v5 libtag1v5-vanilla libtool libv4l-0
#   libv4lconvert0 libvisual-0.4-0 po-debconf
# Suggested packages:
#   dh-make gettext-doc libasprintf-dev libgettextpo-dev gvfs libdv-bin
#   oss-compat libgirepository1.0-dev libglib2.0-doc libgdk-pixbuf2.0-bin
#   | libgdk-pixbuf2.0-dev libxml2-utils gstreamer1.0-doc libtool-doc gcj-jdk
#   libvisual-0.4-plugins libmail-box-perl
# The following NEW packages will be installed:
#   autopoint debhelper dh-autoreconf dh-strip-nondeterminism dwz gettext
#   gettext-base gir1.2-gstreamer-1.0 gstreamer1.0-plugins-base
#   gstreamer1.0-plugins-good gstreamer1.0-x intltool-debian libaa1
#   libarchive-cpio-perl libarchive-zip-perl libblkid-dev libcdparanoia0
#   libcroco3 libdebhelper-perl libdv4 libffi-dev
#   libfile-stripnondeterminism-perl libglib2.0-dev libglib2.0-dev-bin
#   libgstreamer-plugins-good1.0-0 libgstreamer1.0-0-dbg libgstreamer1.0-dev
#   libmail-sendmail-perl libmount-dev libselinux1-dev libsepol1-dev libshout3
#   libsub-override-perl libsys-hostname-long-perl libtag1v5 libtag1v5-vanilla
#   libtool libv4l-0 libv4lconvert0 libvisual-0.4-0 po-debconf
# 0 upgraded, 41 newly installed, 0 to remove and 19 not upgraded.
# Need to get 10.3 MB/12.7 MB of archives.
# After this operation, 51.0 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/main amd64 gettext-base amd64 0.19.8.1-10build1 [50.2 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/main amd64 autopoint all 0.19.8.1-10build1 [412 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/main amd64 libtool all 2.4.6-14 [161 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/main amd64 dh-autoreconf all 19 [16.1 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/main amd64 libdebhelper-perl all 12.10ubuntu1 [62.1 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/main amd64 libarchive-zip-perl all 1.67-2 [90.5 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal/main amd64 libsub-override-perl all 0.09-2 [9,532 B]
# Get:8 http://archive.ubuntu.com/ubuntu focal/main amd64 libfile-stripnondeterminism-perl all 1.7.0-1 [15.9 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal/main amd64 dh-strip-nondeterminism all 1.7.0-1 [5,228 B]
# Get:10 http://archive.ubuntu.com/ubuntu focal/main amd64 dwz amd64 0.13-5 [151 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal/main amd64 libcroco3 amd64 0.6.13-1 [82.5 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal/main amd64 gettext amd64 0.19.8.1-10build1 [895 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal/main amd64 intltool-debian all 0.35.0+20060710.5 [24.9 kB]
# Get:14 http://archive.ubuntu.com/ubuntu focal/main amd64 po-debconf all 1.0.21 [233 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal/main amd64 debhelper all 12.10ubuntu1 [877 kB]
# Get:16 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gir1.2-gstreamer-1.0 amd64 1.16.3-0ubuntu1.1 [72.2 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal/main amd64 libcdparanoia0 amd64 3.10.2+debian-13 [46.7 kB]
# Get:18 http://archive.ubuntu.com/ubuntu focal/main amd64 libvisual-0.4-0 amd64 0.4.0-17 [99.8 kB]
# Get:19 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gstreamer1.0-plugins-base amd64 1.16.3-0ubuntu1.1 [620 kB]
# Get:20 http://archive.ubuntu.com/ubuntu focal/main amd64 libaa1 amd64 1.4p5-46 [47.3 kB]
# Get:21 http://archive.ubuntu.com/ubuntu focal/main amd64 libdv4 amd64 1.0.0-12 [58.0 kB]
# Get:22 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgstreamer-plugins-good1.0-0 amd64 1.16.3-0ubuntu1.1 [68.7 kB]
# Get:23 http://archive.ubuntu.com/ubuntu focal/main amd64 libshout3 amd64 2.4.3-1 [50.6 kB]
# Get:24 http://archive.ubuntu.com/ubuntu focal/main amd64 libtag1v5-vanilla amd64 1.11.1+dfsg.1-0.3ubuntu2 [280 kB]
# Get:25 http://archive.ubuntu.com/ubuntu focal/main amd64 libtag1v5 amd64 1.11.1+dfsg.1-0.3ubuntu2 [11.0 kB]
# Get:26 http://archive.ubuntu.com/ubuntu focal/main amd64 libv4lconvert0 amd64 1.18.0-2build1 [76.5 kB]
# Get:27 http://archive.ubuntu.com/ubuntu focal/main amd64 libv4l-0 amd64 1.18.0-2build1 [41.9 kB]
# Get:28 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gstreamer1.0-plugins-good amd64 1.16.3-0ubuntu1.1 [1,745 kB]
# Get:29 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gstreamer1.0-x amd64 1.16.3-0ubuntu1.1 [74.7 kB]
# Get:30 http://archive.ubuntu.com/ubuntu focal/main amd64 libarchive-cpio-perl all 0.10-1 [9,644 B]
# Get:31 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgstreamer1.0-dev amd64 1.16.3-0ubuntu1.1 [484 kB]
# Get:32 http://archive.ubuntu.com/ubuntu focal/main amd64 libsys-hostname-long-perl all 1.5-1 [11.7 kB]
# Get:33 http://archive.ubuntu.com/ubuntu focal/main amd64 libmail-sendmail-perl all 0.80-1 [22.6 kB]
# Get:34 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgstreamer1.0-0-dbg amd64 1.16.3-0ubuntu1.1 [3,346 kB]
# Fetched 10.3 MB in 2s (6,387 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 41.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package gettext-base.
# (Reading database ... 128221 files and directories currently installed.)
# Preparing to unpack .../00-gettext-base_0.19.8.1-10build1_amd64.deb ...
# Unpacking gettext-base (0.19.8.1-10build1) ...
# Selecting previously unselected package autopoint.
# Preparing to unpack .../01-autopoint_0.19.8.1-10build1_all.deb ...
# Unpacking autopoint (0.19.8.1-10build1) ...
# Selecting previously unselected package libtool.
# Preparing to unpack .../02-libtool_2.4.6-14_all.deb ...
# Unpacking libtool (2.4.6-14) ...
# Selecting previously unselected package dh-autoreconf.
# Preparing to unpack .../03-dh-autoreconf_19_all.deb ...
# Unpacking dh-autoreconf (19) ...
# Selecting previously unselected package libdebhelper-perl.
# Preparing to unpack .../04-libdebhelper-perl_12.10ubuntu1_all.deb ...
# Unpacking libdebhelper-perl (12.10ubuntu1) ...
# Selecting previously unselected package libarchive-zip-perl.
# Preparing to unpack .../05-libarchive-zip-perl_1.67-2_all.deb ...
# Unpacking libarchive-zip-perl (1.67-2) ...
# Selecting previously unselected package libsub-override-perl.
# Preparing to unpack .../06-libsub-override-perl_0.09-2_all.deb ...
# Unpacking libsub-override-perl (0.09-2) ...
# Selecting previously unselected package libfile-stripnondeterminism-perl.
# Preparing to unpack .../07-libfile-stripnondeterminism-perl_1.7.0-1_all.deb ...
# Unpacking libfile-stripnondeterminism-perl (1.7.0-1) ...
# Selecting previously unselected package dh-strip-nondeterminism.
# Preparing to unpack .../08-dh-strip-nondeterminism_1.7.0-1_all.deb ...
# Unpacking dh-strip-nondeterminism (1.7.0-1) ...
# Selecting previously unselected package dwz.
# Preparing to unpack .../09-dwz_0.13-5_amd64.deb ...
# Unpacking dwz (0.13-5) ...
# Selecting previously unselected package libcroco3:amd64.
# Preparing to unpack .../10-libcroco3_0.6.13-1_amd64.deb ...
# Unpacking libcroco3:amd64 (0.6.13-1) ...
# Selecting previously unselected package gettext.
# Preparing to unpack .../11-gettext_0.19.8.1-10build1_amd64.deb ...
# Unpacking gettext (0.19.8.1-10build1) ...
# Selecting previously unselected package intltool-debian.
# Preparing to unpack .../12-intltool-debian_0.35.0+20060710.5_all.deb ...
# Unpacking intltool-debian (0.35.0+20060710.5) ...
# Selecting previously unselected package po-debconf.
# Preparing to unpack .../13-po-debconf_1.0.21_all.deb ...
# Unpacking po-debconf (1.0.21) ...
# Selecting previously unselected package debhelper.
# Preparing to unpack .../14-debhelper_12.10ubuntu1_all.deb ...
# Unpacking debhelper (12.10ubuntu1) ...
# Selecting previously unselected package gir1.2-gstreamer-1.0:amd64.
# Preparing to unpack .../15-gir1.2-gstreamer-1.0_1.16.3-0ubuntu1.1_amd64.deb ...
# Unpacking gir1.2-gstreamer-1.0:amd64 (1.16.3-0ubuntu1.1) ...
# Selecting previously unselected package libcdparanoia0:amd64.
# Preparing to unpack .../16-libcdparanoia0_3.10.2+debian-13_amd64.deb ...
# Unpacking libcdparanoia0:amd64 (3.10.2+debian-13) ...
# Selecting previously unselected package libvisual-0.4-0:amd64.
# Preparing to unpack .../17-libvisual-0.4-0_0.4.0-17_amd64.deb ...
# Unpacking libvisual-0.4-0:amd64 (0.4.0-17) ...
# Selecting previously unselected package gstreamer1.0-plugins-base:amd64.
# Preparing to unpack .../18-gstreamer1.0-plugins-base_1.16.3-0ubuntu1.1_amd64.deb ...
# Unpacking gstreamer1.0-plugins-base:amd64 (1.16.3-0ubuntu1.1) ...
# Selecting previously unselected package libaa1:amd64.
# Preparing to unpack .../19-libaa1_1.4p5-46_amd64.deb ...
# Unpacking libaa1:amd64 (1.4p5-46) ...
# Selecting previously unselected package libdv4:amd64.
# Preparing to unpack .../20-libdv4_1.0.0-12_amd64.deb ...
# Unpacking libdv4:amd64 (1.0.0-12) ...
# Selecting previously unselected package libgstreamer-plugins-good1.0-0:amd64.
# Preparing to unpack .../21-libgstreamer-plugins-good1.0-0_1.16.3-0ubuntu1.1_amd64.deb ...
# Unpacking libgstreamer-plugins-good1.0-0:amd64 (1.16.3-0ubuntu1.1) ...
# Selecting previously unselected package libshout3:amd64.
# Preparing to unpack .../22-libshout3_2.4.3-1_amd64.deb ...
# Unpacking libshout3:amd64 (2.4.3-1) ...
# Selecting previously unselected package libtag1v5-vanilla:amd64.
# Preparing to unpack .../23-libtag1v5-vanilla_1.11.1+dfsg.1-0.3ubuntu2_amd64.deb ...
# Unpacking libtag1v5-vanilla:amd64 (1.11.1+dfsg.1-0.3ubuntu2) ...
# Selecting previously unselected package libtag1v5:amd64.
# Preparing to unpack .../24-libtag1v5_1.11.1+dfsg.1-0.3ubuntu2_amd64.deb ...
# Unpacking libtag1v5:amd64 (1.11.1+dfsg.1-0.3ubuntu2) ...
# Selecting previously unselected package libv4lconvert0:amd64.
# Preparing to unpack .../25-libv4lconvert0_1.18.0-2build1_amd64.deb ...
# Unpacking libv4lconvert0:amd64 (1.18.0-2build1) ...
# Selecting previously unselected package libv4l-0:amd64.
# Preparing to unpack .../26-libv4l-0_1.18.0-2build1_amd64.deb ...
# Unpacking libv4l-0:amd64 (1.18.0-2build1) ...
# Selecting previously unselected package gstreamer1.0-plugins-good:amd64.
# Preparing to unpack .../27-gstreamer1.0-plugins-good_1.16.3-0ubuntu1.1_amd64.deb ...
# Unpacking gstreamer1.0-plugins-good:amd64 (1.16.3-0ubuntu1.1) ...
# Selecting previously unselected package gstreamer1.0-x:amd64.
# Preparing to unpack .../28-gstreamer1.0-x_1.16.3-0ubuntu1.1_amd64.deb ...
# Unpacking gstreamer1.0-x:amd64 (1.16.3-0ubuntu1.1) ...
# Selecting previously unselected package libarchive-cpio-perl.
# Preparing to unpack .../29-libarchive-cpio-perl_0.10-1_all.deb ...
# Unpacking libarchive-cpio-perl (0.10-1) ...
# Selecting previously unselected package libffi-dev:amd64.
# Preparing to unpack .../30-libffi-dev_3.3-4_amd64.deb ...
# Unpacking libffi-dev:amd64 (3.3-4) ...
# Selecting previously unselected package libglib2.0-dev-bin.
# Preparing to unpack .../31-libglib2.0-dev-bin_2.64.6-1~ubuntu20.04.4_amd64.deb ...
# Unpacking libglib2.0-dev-bin (2.64.6-1~ubuntu20.04.4) ...
# Selecting previously unselected package libblkid-dev:amd64.
# Preparing to unpack .../32-libblkid-dev_2.34-0.1ubuntu9.3_amd64.deb ...
# Unpacking libblkid-dev:amd64 (2.34-0.1ubuntu9.3) ...
# Selecting previously unselected package libmount-dev:amd64.
# Preparing to unpack .../33-libmount-dev_2.34-0.1ubuntu9.3_amd64.deb ...
# Unpacking libmount-dev:amd64 (2.34-0.1ubuntu9.3) ...
# Selecting previously unselected package libsepol1-dev:amd64.
# Preparing to unpack .../34-libsepol1-dev_3.0-1ubuntu0.1_amd64.deb ...
# Unpacking libsepol1-dev:amd64 (3.0-1ubuntu0.1) ...
# Selecting previously unselected package libselinux1-dev:amd64.
# Preparing to unpack .../35-libselinux1-dev_3.0-1build2_amd64.deb ...
# Unpacking libselinux1-dev:amd64 (3.0-1build2) ...
# Selecting previously unselected package libglib2.0-dev:amd64.
# Preparing to unpack .../36-libglib2.0-dev_2.64.6-1~ubuntu20.04.4_amd64.deb ...
# Unpacking libglib2.0-dev:amd64 (2.64.6-1~ubuntu20.04.4) ...
# Selecting previously unselected package libgstreamer1.0-dev:amd64.
# Preparing to unpack .../37-libgstreamer1.0-dev_1.16.3-0ubuntu1.1_amd64.deb ...
# Adding 'diversion of /usr/bin/dh_gstscancodecs to /usr/bin/dh_gstscancodecs-gst0.10 by libgstreamer1.0-dev'
# Adding 'diversion of /usr/share/man/man1/dh_gstscancodecs.1.gz to /usr/share/man/man1/dh_gstscancodecs.1.gz-gst0.10 by libgstreamer1.0-dev'
# Unpacking libgstreamer1.0-dev:amd64 (1.16.3-0ubuntu1.1) ...
# Selecting previously unselected package libsys-hostname-long-perl.
# Preparing to unpack .../38-libsys-hostname-long-perl_1.5-1_all.deb ...
# Unpacking libsys-hostname-long-perl (1.5-1) ...
# Selecting previously unselected package libmail-sendmail-perl.
# Preparing to unpack .../39-libmail-sendmail-perl_0.80-1_all.deb ...
# Unpacking libmail-sendmail-perl (0.80-1) ...
# Selecting previously unselected package libgstreamer1.0-0-dbg:amd64.
# Preparing to unpack .../40-libgstreamer1.0-0-dbg_1.16.3-0ubuntu1.1_amd64.deb ...
# Unpacking libgstreamer1.0-0-dbg:amd64 (1.16.3-0ubuntu1.1) ...
# Setting up libglib2.0-dev-bin (2.64.6-1~ubuntu20.04.4) ...
# Setting up libblkid-dev:amd64 (2.34-0.1ubuntu9.3) ...
# Setting up libcdparanoia0:amd64 (3.10.2+debian-13) ...
# Setting up gir1.2-gstreamer-1.0:amd64 (1.16.3-0ubuntu1.1) ...
# Setting up libtag1v5-vanilla:amd64 (1.11.1+dfsg.1-0.3ubuntu2) ...
# Setting up gstreamer1.0-x:amd64 (1.16.3-0ubuntu1.1) ...
# Setting up libtool (2.4.6-14) ...
# Setting up libvisual-0.4-0:amd64 (0.4.0-17) ...
# Setting up libarchive-zip-perl (1.67-2) ...
# Setting up libdebhelper-perl (12.10ubuntu1) ...
# Setting up libsepol1-dev:amd64 (3.0-1ubuntu0.1) ...
# Setting up gettext-base (0.19.8.1-10build1) ...
# Setting up libffi-dev:amd64 (3.3-4) ...
# Setting up libgstreamer-plugins-good1.0-0:amd64 (1.16.3-0ubuntu1.1) ...
# Setting up gstreamer1.0-plugins-base:amd64 (1.16.3-0ubuntu1.1) ...
# Setting up libshout3:amd64 (2.4.3-1) ...
# Setting up autopoint (0.19.8.1-10build1) ...
# Setting up libcroco3:amd64 (0.6.13-1) ...
# Setting up dwz (0.13-5) ...
# Setting up libtag1v5:amd64 (1.11.1+dfsg.1-0.3ubuntu2) ...
# Setting up libdv4:amd64 (1.0.0-12) ...
# Setting up libarchive-cpio-perl (0.10-1) ...
# Setting up libv4lconvert0:amd64 (1.18.0-2build1) ...
# Setting up libsub-override-perl (0.09-2) ...
# Setting up libsys-hostname-long-perl (1.5-1) ...
# Setting up libmount-dev:amd64 (2.34-0.1ubuntu9.3) ...
# Setting up libgstreamer1.0-0-dbg:amd64 (1.16.3-0ubuntu1.1) ...
# Setting up libaa1:amd64 (1.4p5-46) ...
# Setting up libfile-stripnondeterminism-perl (1.7.0-1) ...
# Setting up gettext (0.19.8.1-10build1) ...
# Setting up libselinux1-dev:amd64 (3.0-1build2) ...
# Setting up intltool-debian (0.35.0+20060710.5) ...
# Setting up libv4l-0:amd64 (1.18.0-2build1) ...
# Setting up libmail-sendmail-perl (0.80-1) ...
# Setting up libglib2.0-dev:amd64 (2.64.6-1~ubuntu20.04.4) ...
# Setting up dh-strip-nondeterminism (1.7.0-1) ...
# Setting up gstreamer1.0-plugins-good:amd64 (1.16.3-0ubuntu1.1) ...
# Setting up po-debconf (1.0.21) ...
# Setting up dh-autoreconf (19) ...
# Setting up debhelper (12.10ubuntu1) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for libglib2.0-0:amd64 (2.64.6-1~ubuntu20.04.4) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Setting up libgstreamer1.0-dev:amd64 (1.16.3-0ubuntu1.1) ...

# %%
# !sudo apt-get install build-essential libsqlite3-dev sqlite3 bzip2 libbz2-dev zlib1g-dev libssl-dev openssl libgdbm-dev libgdbm-compat-dev liblzma-dev libreadline-dev libncursesw5-dev libffi-dev uuid-dev libffi6
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# E: Unable to locate package libffi6

# %%
# !sudo apt-get install libffi-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libffi-dev is already the newest version (3.3-4).
# libffi-dev set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 19 not upgraded.

# %%
# !buildozer init
# Out:
# Buildozer is running as root!
# This is not recommended, and may lead to problems later.
# Are you sure you want to continue [y/n]? y
# File buildozer.spec created, ready to customize!

# %%
# !buildozer -v android debug
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# [DEBUG]:
# [DEBUG]:   	**********************************************************************
# [DEBUG]:   	***                                                                ***
# [DEBUG]:   	***   OpenSSL has been successfully configured                     ***
# [DEBUG]:   	***                                                                ***
# [DEBUG]:   	***   If you encounter a problem while building, please open an    ***
# [DEBUG]:   	***   issue on GitHub <https://github.com/openssl/openssl/issues>  ***
# [DEBUG]:   	***   and include the output from the following command:           ***
# [DEBUG]:   	***                                                                ***
# [DEBUG]:   	***       perl configdata.pm --dump                                ***
# [DEBUG]:   	***                                                                ***
# [DEBUG]:   	***   (If you are new to OpenSSL, you might want to consult the    ***
# [DEBUG]:   	***   'Troubleshooting' section in the INSTALL file first)         ***
# [DEBUG]:   	***                                                                ***
# [DEBUG]:   	**********************************************************************
# [INFO]:    Applying patch disable-sover.patch
# [DEBUG]:   -> running patch -t -d /content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/openssl/armeabi-v7a__ndk_target_21/openssl1.1 -p1 -i /content/.buildozer/android/platform/python-for-android/pythonforandroid/recipes/openssl/disable-sover.patch
# [DEBUG]:   	patching file Makefile
# [DEBUG]:   -> running make build_libs
# [DEBUG]:   	/usr/bin/perl "-I." -Mconfigdata "util/dofile.pl" \
# [DEBUG]:   	    "-oMakefile" include/crypto/bn_conf.h.in > include/crypto/bn_conf.h
# [DEBUG]:   	/usr/bin/perl "-I." -Mconfigdata "util/dofile.pl" \
# [DEBUG]:   	    "-oMakefile" include/crypto/dso_conf.h.in > include/crypto/dso_conf.h
# [DEBUG]:   	/usr/bin/perl "-I." -Mconfigdata "util/dofile.pl" \
# [DEBUG]:   	    "-oMakefile" include/openssl/opensslconf.h.in > include/openssl/opensslconf.h
# [DEBUG]:   	make depend && make _build_libs
# [DEBUG]:   	make[1]: Entering directory '/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/openssl/armeabi-v7a__ndk_target_21/openssl1.1'
# [DEBUG]:   	make[1]: Leaving directory '/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/openssl/armeabi-v7a__ndk_target_21/openssl1.1'
# [DEBUG]:   	make[1]: Entering directory '/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/other_builds/openssl/armeabi-v7a__ndk_target_21/openssl1.1'
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF apps/app_rand.d.tmp -MT apps/app_rand.o -c -o apps/app_rand.o apps/app_rand.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF apps/apps.d.tmp -MT apps/apps.o -c -o apps/apps.o apps/apps.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF apps/bf_prefix.d.tmp -MT apps/bf_prefix.o -c -o apps/bf_prefix.o apps/bf_prefix.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF apps/opt.d.tmp -MT apps/opt.o -c -o apps/opt.o apps/opt.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF apps/s_cb.d.tmp -MT apps/s_cb.o -c -o apps/s_cb.o apps/s_cb.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF apps/s_socket.d.tmp -MT apps/s_socket.o -c -o apps/s_socket.o apps/s_socket.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	llvm-ar rs apps/libapps.a apps/app_rand.o apps/apps.o apps/bf_prefix.o apps/opt.o apps/s_cb.o apps/s_socket.o
# [DEBUG]:   	llvm-ar: warning: creating apps/libapps.a
# [DEBUG]:   	: apps/libapps.a || echo Never mind.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/aes/aes_cbc.d.tmp -MT crypto/aes/aes_cbc.o -c -o crypto/aes/aes_cbc.o crypto/aes/aes_cbc.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/aes/aes_cfb.d.tmp -MT crypto/aes/aes_cfb.o -c -o crypto/aes/aes_cfb.o crypto/aes/aes_cfb.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/aes/aes_core.d.tmp -MT crypto/aes/aes_core.o -c -o crypto/aes/aes_core.o crypto/aes/aes_core.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/aes/aes_ecb.d.tmp -MT crypto/aes/aes_ecb.o -c -o crypto/aes/aes_ecb.o crypto/aes/aes_ecb.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/aes/aes_ige.d.tmp -MT crypto/aes/aes_ige.o -c -o crypto/aes/aes_ige.o crypto/aes/aes_ige.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/aes/aes_misc.d.tmp -MT crypto/aes/aes_misc.o -c -o crypto/aes/aes_misc.o crypto/aes/aes_misc.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/aes/aes_ofb.d.tmp -MT crypto/aes/aes_ofb.o -c -o crypto/aes/aes_ofb.o crypto/aes/aes_ofb.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/aes/aes_wrap.d.tmp -MT crypto/aes/aes_wrap.o -c -o crypto/aes/aes_wrap.o crypto/aes/aes_wrap.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/aria/aria.d.tmp -MT crypto/aria/aria.o -c -o crypto/aria/aria.o crypto/aria/aria.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/asn1/a_bitstr.d.tmp -MT crypto/asn1/a_bitstr.o -c -o crypto/asn1/a_bitstr.o crypto/asn1/a_bitstr.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/asn1/a_d2i_fp.d.tmp -MT crypto/asn1/a_d2i_fp.o -c -o crypto/asn1/a_d2i_fp.o crypto/asn1/a_d2i_fp.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/asn1/a_digest.d.tmp -MT crypto/asn1/a_digest.o -c -o crypto/asn1/a_digest.o crypto/asn1/a_digest.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/asn1/a_dup.d.tmp -MT crypto/asn1/a_dup.o -c -o crypto/asn1/a_dup.o crypto/asn1/a_dup.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/asn1/a_gentm.d.tmp -MT crypto/asn1/a_gentm.o -c -o crypto/asn1/a_gentm.o crypto/asn1/a_gentm.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/asn1/a_i2d_fp.d.tmp -MT crypto/asn1/a_i2d_fp.o -c -o crypto/asn1/a_i2d_fp.o crypto/asn1/a_i2d_fp.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/asn1/a_int.d.tmp -MT crypto/asn1/a_int.o -c -o crypto/asn1/a_int.o crypto/asn1/a_int.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/asn1/a_mbstr.d.tmp -MT crypto/asn1/a_mbstr.o -c -o crypto/asn1/a_mbstr.o crypto/asn1/a_mbstr.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/asn1/a_object.d.tmp -MT crypto/asn1/a_object.o -c -o crypto/asn1/a_object.o crypto/asn1/a_object.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/asn1/a_octet.d.tmp -MT crypto/asn1/a_octet.o -c -o crypto/asn1/a_octet.o crypto/asn1/a_octet.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/asn1/a_print.d.tmp -MT crypto/asn1/a_print.o -c -o crypto/asn1/a_print.o crypto/asn1/a_print.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/asn1/a_sign.d.tmp -MT crypto/asn1/a_sign.o -c -o crypto/asn1/a_sign.o crypto/asn1/a_sign.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/asn1/a_strex.d.tmp -MT crypto/asn1/a_strex.o -c -o crypto/asn1/a_strex.o crypto/asn1/a_strex.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/asn1/a_strnid.d.tmp -MT crypto/asn1/a_strnid.o -c -o crypto/asn1/a_strnid.o crypto/asn1/a_strnid.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/asn1/a_time.d.tmp -MT crypto/asn1/a_time.o -c -o crypto/asn1/a_time.o crypto/asn1/a_time.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/asn1/a_type.d.tmp -MT crypto/asn1/a_type.o -c -o crypto/asn1/a_type.o crypto/asn1/a_type.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/asn1/a_utctm.d.tmp -MT crypto/asn1/a_utctm.o -c -o crypto/asn1/a_utctm.o crypto/asn1/a_utctm.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/asn1/a_utf8.d.tmp -MT crypto/asn1/a_utf8.o -c -o crypto/asn1/a_utf8.o crypto/asn1/a_utf8.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/asn1/a_verify.d.tmp -MT crypto/asn1/a_verify.o -c -o crypto/asn1/a_verify.o crypto/asn1/a_verify.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/asn1/ameth_lib.d.tmp -MT crypto/asn1/ameth_lib.o -c -o crypto/asn1/ameth_lib.o crypto/asn1/ameth_lib.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/asn1/asn1_err.d.tmp -MT crypto/asn1/asn1_err.o -c -o crypto/asn1/asn1_err.o crypto/asn1/asn1_err.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/asn1/asn1_gen.d.tmp -MT crypto/asn1/asn1_gen.o -c -o crypto/asn1/asn1_gen.o crypto/asn1/asn1_gen.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/asn1/asn1_item_list.d.tmp -MT crypto/asn1/asn1_item_list.o -c -o crypto/asn1/asn1_item_list.o crypto/asn1/asn1_item_list.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/asn1/asn1_lib.d.tmp -MT crypto/asn1/asn1_lib.o -c -o crypto/asn1/asn1_lib.o crypto/asn1/asn1_lib.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/asn1/asn1_par.d.tmp -MT crypto/asn1/asn1_par.o -c -o crypto/asn1/asn1_par.o crypto/asn1/asn1_par.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/asn1/asn_mime.d.tmp -MT crypto/asn1/asn_mime.o -c -o crypto/asn1/asn_mime.o crypto/asn1/asn_mime.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/asn1/asn_moid.d.tmp -MT crypto/asn1/asn_moid.o -c -o crypto/asn1/asn_moid.o crypto/asn1/asn_moid.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# ...
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/srp/srp_lib.d.tmp -MT crypto/srp/srp_lib.o -c -o crypto/srp/srp_lib.o crypto/srp/srp_lib.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/srp/srp_vfy.d.tmp -MT crypto/srp/srp_vfy.o -c -o crypto/srp/srp_vfy.o crypto/srp/srp_vfy.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/stack/stack.d.tmp -MT crypto/stack/stack.o -c -o crypto/stack/stack.o crypto/stack/stack.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/store/loader_file.d.tmp -MT crypto/store/loader_file.o -c -o crypto/store/loader_file.o crypto/store/loader_file.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/store/store_err.d.tmp -MT crypto/store/store_err.o -c -o crypto/store/store_err.o crypto/store/store_err.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/store/store_init.d.tmp -MT crypto/store/store_init.o -c -o crypto/store/store_init.o crypto/store/store_init.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/store/store_lib.d.tmp -MT crypto/store/store_lib.o -c -o crypto/store/store_lib.o crypto/store/store_lib.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/store/store_register.d.tmp -MT crypto/store/store_register.o -c -o crypto/store/store_register.o crypto/store/store_register.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/store/store_strings.d.tmp -MT crypto/store/store_strings.o -c -o crypto/store/store_strings.o crypto/store/store_strings.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/threads_none.d.tmp -MT crypto/threads_none.o -c -o crypto/threads_none.o crypto/threads_none.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/threads_pthread.d.tmp -MT crypto/threads_pthread.o -c -o crypto/threads_pthread.o crypto/threads_pthread.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/threads_win.d.tmp -MT crypto/threads_win.o -c -o crypto/threads_win.o crypto/threads_win.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/ts/ts_asn1.d.tmp -MT crypto/ts/ts_asn1.o -c -o crypto/ts/ts_asn1.o crypto/ts/ts_asn1.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^
# [DEBUG]:   	1 warning generated.
# [DEBUG]:   	armv7a-linux-androideabi21-clang  -I. -Iinclude -fPIC -pthread -target armv7a-linux-androideabi21 -fomit-frame-pointer -march=armv7-a -mfloat-abi=softfp -mfpu=vfp -mthumb -fPIC -DOPENSSL_USE_NODELETE -DOPENSSL_PIC -DOPENSSLDIR="\"/usr/local/ssl\"" -DENGINESDIR="\"/usr/local/lib/engines-1.1\"" -DNDEBUG -D__ANDROID_API__=21 -DANDROID -I/root/.buildozer/android/platform/android-ndk-r25b/toolchains/llvm/prebuilt/linux-x86_64/sysroot/usr/include -I/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a/build/python-installs/myeapp/armeabi-v7a/include/python3.9 -MMD -MF crypto/ts/ts_conf.d.tmp -MT crypto/ts/ts_conf.o -c -o crypto/ts/ts_conf.o crypto/ts/ts_conf.c
# [DEBUG]:   	In file included from <built-in>:386:
# [DEBUG]:   	<command line>:6:9: warning: '__ANDROID_API__' macro redefined [-Wmacro-redefined]
# [DEBUG]:   	#define __ANDROID_API__ 21
# [DEBUG]:   	        ^
# [DEBUG]:   	<built-in>:379:9: note: previous definition is here
# [DEBUG]:   	#define __ANDROID_API__ __ANDROID_MIN_SDK_VERSION__
# [DEBUG]:   	        ^

# %%
# !buildozer android clean
